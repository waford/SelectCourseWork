# %% [markdown]
# # Homework 1
#
# 29 points
#
# ## Due January 28, before class

# %% [markdown]
# **Collaboration statement:**

# %% [markdown]
# ## 1.  Get logged in to [PACE-ICE](https://docs.pace.gatech.edu/training/pace-ice/) (1 point)
#
# - There are orientation [slides](https://pace.gatech.edu/sites/default/files/pace-ice_orientation_2.pdf)
#     - You have to be on campus or using the campus VPN to connect
# - After you connect you will be using a shell to interact with the linux operating system on a login node.  If this is your first time using linux, PACE also has [materials to help you](https://docs.pace.gatech.edu/training/linux101/)
#
# Once you are logged in, in the cell below create a tuple with your username and your numeric user id.  You can find your numeric user id by running the command `id -u`.  For example, I would write
#
# ```julia
# ("tisaac3", 177194)
# ```

# %%
("wford32", 960502)
throw(MethodError)
# Out:
# MethodError
#
# Stacktrace:
#  [1] top-level scope at In[12]:2

# %% [markdown]
# This is not asking you to divulge any private or secure information: your id is availabe to anyone else on the system, and in fact that is how we will check your answer.

# %%
# The grading script will run this on the pace-ice system
username, userid = ans
if endswith(read(`hostname`, String), "pace.gatech.edu")
    record = r"uid=(\d*)\((\w*)\)";
    fullrecord = read(`id -- $username`, String)
    result = match(record, fullrecord)
    @assert string(userid) == result[1]
    @assert username == result[2]
end

# %% [markdown]
# ## 2. Big O notation (3 points)
#
# Prove that if $f(x) > 0$ and $g(x) > 0$ for all $x$ then $f\in \Theta(g)$ if and only if $g \in \Theta(f)$.

# %% [markdown]
# If $f \in \Theta(g)$, then $f \in O(g)$ and $f \in \Omega(g)$. If $f \in O(g)$, then there is some $M, N$ such that $f(x) \leq Mg(x)$ for all $x \geq N$ (we know that $f(x) > 0$ and $g(x) > 0$ for all $x$, so we can ignore the absolute value signs. Dividigin by $M$, we get that $\frac{1}{M}f(x) \leq g(x)$ for all $x \geq N$. If we call $\frac{1}{M}$ $m$, we get that $mf(x) \leq g(x)$ for all $x \geq N$, which is the definition for $g(x) \in \Omega(f)$. So we know that if $f(x) \in O(g)$, then $g(x) \in \Omega(f)$.
#
# If $f(x) \in \Omega(g)$, then we can say that there is some $m,N$ such that $mg(x) \leq f(x)$ for all $x \geq N$. If we call $\frac{1}{m}$ $M$, then we can say that $g(x) \leq Mf(x)$ for all $x \geq N$. Now we have the definition for $g(x) \in O(f)$. So if $f(x) \in \Omega(g)$, then $g(x) \in O(f)$.
#
# We can say that if $f \in \Theta(g)$, then $f \in \Omega(g)$ and $f \in O(g)$. From above, we can say that $g \in O(f)$ and $f \in \Omega(f)$, which means that $g \in \Theta(f)$.
#
# If $g \in Theta(f)$, then by the same argument, $f \in \Omega(g)$ and $f \in O(g)$, so $f \in \Theta(g)$.
#
# Thus if $f(x) > 0$ and $g(x) < 0$ for all $x$, then $f \in \Theta(g)$ if and only if $g \in \Theta(f)$

# %% [markdown]
# ### 3. Master Theorem (5 points)
#
# Strassen's algorithm is a method for mutliplying two matrices, $C\gets AB$ (to simplify, assume they are square, $A,B,C\in \mathbb{R}^{n\times n}$).  In Strassen's algorithm, we
#
# 1. split $A$ and $B$ in half like so (this splitting in mostly symbolic and implies only $O(1)$ work)
#
# $$
# \left[\begin{array}{c|c} A_{11} & A_{12} \\ \hline A_{21} & A_{22} \end{array}\right]
# \gets A, \quad A_{\{1,2\}\{1,2\}}\in \mathbb{R}^{\frac{n}{2} \times \frac{n}{2}}
# $$
#
# 2. compute some intermediate matrix sums
#
# $$
# \begin{aligned}
# S_1 &\gets A_{11} + A_{22}, &
# S_2 &\gets B_{11} + B_{22}, \\
# S_3 &\gets A_{21} + A_{22}, &
# S_4 &\gets B_{12} - B_{22}, \\
# S_5 &\gets B_{21} - B_{11}, &
# S_6 &\gets A_{11} + A_{12}, \\
# S_7 &\gets A_{21} - A_{11}, &
# S_8 &\gets B_{11} + B_{12}, \\
# S_9 &\gets A_{12} - A_{22}, &
# S_{10} &\gets B_{21} + B_{22}.
# \end{aligned}
# $$
#
# 3. compute some matrix products
#
# $$
# \begin{aligned}
# M_1 &\gets S_1 S_2, &
# M_2 &\gets S_3 B_{11}, \\
# M_3 &\gets A_{11} S_4, &
# M_4 &\gets A_{22} S_5, \\
# M_5 &\gets S_6 B_{22}, &
# M_6 &\gets S_7 S_8, \\
# M_7 &\gets S_9 S_{10}.
# \end{aligned}
# $$
#
# 4. compute the final sums
#
# $$
# C \gets
# \left[
# \begin{array}{c|c}
# M_1 + M_4 - M_5 + M_7 & M_3 + M_5, \\ \hline
# M_2 + M_4 & M_1 - M_2 + M_3 + M_6
# \end{array}
# \right]
# $$
#
# Assuming Strassen's algorithm uses the same steps recursively for the matrix products in step 3, what is the recurrence for the time complexity?  Namely, in
#
# $$T(n) = f(n) + a T(n/b),$$
#
# Say what $a$, $b$, and the $\Theta$ class of $f(n)$ are, and then use the Master Theorem to say what the $\Theta$ class of $T(n)$ is.

# %% [markdown]
# The work in each recurrance, $f(n)$ is done during the matrix additions in step 2 and 4. Because each split matrix contains $\frac{n^2}{2}$ elements, adding (or subtracting) any two matrices is an  $\Theta(n^2)$ operation. There are a constant number of these operations in each recurrance, so we can say that $f(n) \in \Theta(n^2)$. The recurrance occures in step 3, where we can use the same algorithm to multiply each split matrix. There are 7 recurrent calls (i.e. $a=7$) that are made, all on matrices with half the number of rows as the first (i.e. $b=2$), so for the Master Theorem, $T(n) = \Theta(n^2) + 7T\left(\dfrac{n}{2}\right)$. Computing the critical exponent: $c_{crit} = \log_ba = \log_27 \approx 2.8704 \geq 2$. This falls into the first case of the Master Theorem, so we know that $T(n) = \Theta(n^{\log_27})\approx \Theta(n^{2.8704})$.

# %% [markdown]
# ## 4. Work/depth
#
# A unit lower bidiagonal matrix looks like the following:
#
# $$
# A =
# \begin{bmatrix}
# 1      & 0      & \dots  & \dots   & 0  \\
# a_1    & 1      & \ddots &         & \vdots \\
# 0      & a_2    & \ddots & \ddots  & \vdots \\
# \vdots & \ddots & \ddots & 1       & 0 \\
# 0      & \dots  & 0      & a_{n-1} & 1
# \end{bmatrix}.
# $$

# %% [markdown]
# The following function multiplies $A$ (represented by the vector $[a_1, \dots, a_{n-1}]$ by a vector $x$, $y\gets A x$:

# %%
function unit_lower_bidiagonal_multiply!(a, x, y)
    n = size(x,1)
    @assert size(a,1) == n - 1
    @assert size(y,1) == n
    y[1] = x[1]
    for i = 1:n-1
        y[i+1] = x[i] * a[i] + x[i+1]
    end
    return nothing
end
# Out:
# unit_lower_bidiagonal_multiply! (generic function with 1 method)

# %% [markdown]
# The following function reverses the above, $x \gets A^{-1} y$:

# %%
function unit_lower_bidiagonal_solve!(a, y, x)
    n = size(x,1)
    @assert size(a,1) == n - 1
    @assert size(y,1) == n
    x[1] = y[1]
    for i = 1:n-1
        x[i+1] = y[i+1] - x[i] * a[i]
    end
    return nothing
end
# Out:
# unit_lower_bidiagonal_solve! (generic function with 1 method)

# %% [markdown]
# ### a. (3 points)
#
# Draw circuit diagrams for $y \gets Ax$ and $x \gets A^{-1} y$ for $n=4$.  You may use a computer for your drawings or draw by hand and take a picture.  If you want to include a picture in a markdown cell, you do it like `![](hw1p4a1.png)`, where `hwp4a1.png` is the picture file.

# %% [markdown]
# $y \rightarrow Ax$: ![](hw1p4a1.png)  $x \rightarrow A^{-1}y$: ![](hw1p4a2.png)

# %% [markdown]
# ### b. (2 points)
#
# What is $W_{Ax}(n)$, the work of $y\gets Ax$ as a function of $n$?
#
# What is $D_{Ax}(n)$, the depth of $y\gets Ax$ as a function of $n$?
#
# What is $W_{A^{-1}y}(n)$, the work of $x \gets A^{-1} y$ as a function of $n$?
#
# What is $D_{A^{-1}y}(n)$, the depth of $x \gets A^{-1} y$ as a function of $n$?
#
# (For these values, only consider arithmetic operations, not assignments)

# %% [markdown]
# For $W_{Ax}(4)$, there are 6 operations. For every element in $Y$ is computed using 2 operations, excluding the first element, so $W_{Ax}(n) = 2(n-1)$.
#
# The depth: $D_Ax(4)$ is 2. As every iteration of the loop is independnet, and only requires 2 operations, this depth is constant and $D_{Ax}(n) = 2$
#
#
# For $W_{A^{-1}y}$ there are a total of 6 operations to compute all the elements of $x$. Excluding the first element, each element of $x$ requries 2 operations, so the work is $W_{A^{-1}y} = 2(n-1)$
#
#
# The depth $D_{A^{-1}y}(4)$ is 6. Each element of $x$ execpt the first one depends on the one computed before it, and requries 2 operations to compute, so we can say that the depth $D_{A^{-1}y}(n) = 2(n-1)$

# %% [markdown]
# ## 5. Work/depth of quicksort

# %% [markdown]
# ### a. (2 points)
# Write an implementation of quicksort that uses `@spawn` and `fetch` to parallelize the recursive step.
#
# - Use `rand(1:n)` to pick the pivot out of an array of length $n$
# - Your function should return a tuple `(W, D)` of two integers:
#     - `W` is the total number of comparisons performed by quicksort
#     - `D` is the depth of comparisons that occur in sequence
#
#   So if quicksort performs $C$ comparisons before recursion, and the recursive calls
#   have work and depth $(W_1, D_1)$ and $(W_2, D_2)$, then the total work will be $C + W_1 + W_2$ and depth will be $C + \max(D_1, D_2)$.

# %%
import Base.Threads: @spawn

            
function swap(A, i, j)
        tmp = A[i]
        A[i] = A[j]
        A[j] = tmp
        return nothing
end

@views function parallel_quicksort!(A)::Tuple{Int64,Int64}
    c = 0
    n = size(A,1)
    if n <= 1
        return (0,0)
    end
    #Select random pivot index
    pivot_ind = rand(1:n)
    pivot = A[pivot_ind]
    #Make pivot last value in array
    swap(A, pivot_ind, n)
    i = 1
    for j in 1:n
        # Move all elements which are smaller than the pivot to index i and increment i
        # Swap pivot and element at i, so all elements in A[1:i-1] are < pivot, all elements in A[i:n] are >= pivot 
        if A[j] < pivot
            swap(A, i,j)
            i += 1
            c+=1
        end
    end
    swap(A, i, n)
    r1 = @spawn parallel_quicksort!(A[1:i])
    r2 = @spawn parallel_quicksort!(A[i+1:n])

    work1, depth1 = fetch(r1)
    work2, depth2 = fetch(r2)
    W = c + work1 + work2
    D = c + max(depth1, depth2)   
    return (W, D)
    throw(MethodError)
end
# Out:
# parallel_quicksort! (generic function with 1 method)

# %%
for i in 1:100
    A = rand(1:3, 100)
    W, D = parallel_quicksort!(A)
    @assert issorted(A)
end

# %%
A = rand(1:3,100)
W, D = parallel_quicksort!(A)
@assert issorted(A)

# %% [markdown]
# ### b. (3 points)
#
# Create a scatter plot using `parallel_quicksort!`:
# - x-axis: the work $W$
# - y-axis: the available parallelism $W$ / $D$
# - for random arrays (`rand(n)`) for $n = 10, 20, \dots,  100$
# - generate 1000 samples for each $n$

# %%
import Pkg
Pkg.add("Plots")
Pkg.add("PyPlot")
using Plots
# Out:
#   Resolving package versions...
#    Updating `~/.julia/environments/v1.4/Project.toml`
#  [no changes]
#    Updating `~/.julia/environments/v1.4/Manifest.toml`
#  [no changes]
#   Resolving package versions...
#    Updating `~/.julia/environments/v1.4/Project.toml`
#  [no changes]
#    Updating `~/.julia/environments/v1.4/Manifest.toml`
#  [no changes]

# %%
p = scatter(title="Scatter Plot of parallel_quicksort! Work vs Avaliable Parallelism")

for n = 10:10:100
    x = Array{Int64}(undef, 1000)
    y = Array{Float64}(undef, 1000)
    for i in 1:1000
        A = rand(n)
        W, D = parallel_quicksort!(A)
        x[i] = W
        y[i] = W / D
    end
    scatter!(p,x,y, label=string(n), markershape=Plots.supported_markers()[round(Int,n/10) + 2])
end
ylabel!(p,"Avaliable Parallelism (W/D)")
xlabel!(p,"Work (W)")
@show p


#throw(MethodError)
# Out:
# p = Plot{Plots.GRBackend() n=10}

# %% [markdown]
# ## 6. Comparing speedups
#
# You are given two parallel algorithms, $A$ and $B$, for solving a problem of size $n$:
#
# $$\begin{aligned}T_A(n,n^2) &= \sqrt{n}, \\
# T_B(n,n) &= n.\end{aligned}$$

# %% [markdown]
# ### a. (3 points)
#
# Which algorithm will run faster on a machine with $p$ processors?  Do not make any particular assumptions on $p$.  Instead, consider all possible values of $p$.

# %% [markdown]
# Assuming that both algorithms exhibits the efficiency scaling described in Brent's Law, we can say the following for both algorithms:
#
# $$T_A(n,p) \in \Theta\left(\dfrac{n^2}{p}\sqrt{n}\right) \text{ for } p \leq n^2$$
# $$T_A(n,p) = \begin{cases} \dfrac{n^2}{p}\sqrt{n} &p \leq n^2 \\ \sqrt{n} &p \geq n^2 \end{cases}$$
#
# $$T_B(n,p) \in \Theta\left(\dfrac{n}{p}\right) \text{ for } p \leq n$$
# $$T_B(n,p) = \begin{cases} \dfrac{n^2}{p} &p \leq n \\ n &p \geq n \end{cases}$$
#
# Clearly for $p \leq n$, $T_b$ has a faster run time than $T_A$, and for $p \geq n^2$, $T_A$ will have a faster runtime than $T_B$. To find at what point $T_A$ becomes faster than $T_B$, we need to find $p$ such that $\frac{n^2\sqrt{n}}{p} = n$. For this condition, we get $p=n\sqrt{n}$. We can now say that $T_B$ will run faster on a machine with $p \leq n\sqrt{n}$ processors while $T_A$ will run faster on a machine with $p \geq n\sqrt{n}$ processors.

# %% [markdown]
# ### b. (2 points)
#
# Now assume you have to run $k$ independent instances of the same problem, each of size $n$ on a $p = n^2$ processor machine.
# You can
# run multiple instances concurrently each using only a subset of
# the available processors. Which algorithm will finish the fastest?
# Consider all possible values for $k$.

# %% [markdown]
# The efficeny for $A$ with $p<n^2$ is $E_A(n,p) = \frac{n^2\sqrt{n}}{p\left(\frac{n^2}{p}\sqrt{n}\right)} = 1$. Using less than $n^2$ processors does not increase the efficeny of algorithm $A$, so we can concluding that the best time for $k$ instances will be $T_A = \Theta(k\sqrt{n})$.
#
# For B, the efficeny is 1 for $p \leq n$ proccssors and $\frac{n}{p}$ for $p \geq n$ processors. Using $n$ proccessors to maintain ideal efficeny, the number of instances that can be run concurently is $n$, so the runtime of B is $T_B = \Theta(\lceil\frac{k}{n}\rceil n) = \Theta((\frac{k}{n}+1)n) = \Theta(k+n)$.
#
# For $k = \sqrt{n}$ we see that the runtimes are on the same scale: $T_A \in \Theta(n)$, $T_B \in \Theta(n + \sqrt{n}) = \Theta(n)$. Fpr $k < \sqrt{n}$, A will be faster, , while for $k > \sqrt{n}$, algorithm B will be faster.

# %% [markdown]
# ## 7. Memory constraints
#
# The following information is given on a parallel algorithm:
#
# - Serial run time: $n \log n$
# - Parallel run time: $\frac{n \log n}{p} + p \log n$
# - Memory required per processor: $\frac{n}{p}$

# %% [markdown]
# ### a. (3 points)
#
# Find the largest number of processors (as a function of $n$) that can be used while being optimally efficient.  In other words, you are being asked to find a function $f(n)$ such
# that $E(n,p(n))\in \Theta(1)$ if and only if $p(n) \in O(f(n))$.

# %% [markdown]
# Using the serial and parallel run times, we can say that the efficiency for $p$ processors: $E(p)$ is: $$E(p) \in \Theta \left(\frac{n\log n}{p\left(\frac{n\log n}{p} + p\log n\right)}\right) = \Theta \left(\frac{n\log n}{n\log n + p^2 \log n}\right) = \Theta(1)$$ $$p(n) = \sqrt{n}$$

# %% [markdown]
# ### b. (2 points)
#
# Assuming that we want to run this algorithm on a machine where the memory available per processor is fixed, can we scale the number of processors as $O(f(n))$ as derived above?  Why or why not?

# %% [markdown]
# The memory used by this algorithm is $m(n, p) = \frac{n}{p}$. From part a., we derived $p(n)= \sqrt{n}$, so the memory used is $m(n) = \frac{n}{\sqrt{n}} \in O(\sqrt{n})$.However, the memory available per processors is fixed, so the memory avalibe to each process is $\Theta(1)$. However, the memory requred by each processor is $O(\sqrt{n})$, so we would be unable to scale the processors as $O(\sqrt{n})$.
